

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache().shuffle(100).prefetch(AUTOTUNE)

validation_dataset = validation_dataset.cache().prefetch(AUTOTUNE)

# %%
data_augmentation = keras.Sequential([

    layers.RandomFlip("horizontal"),

    layers.RandomRotation(0.1),

    layers.RandomZoom(0.1)

])

# %%
model = models.Sequential([

    data_augmentation,

    layers.Rescaling(1./255),

    layers.Conv2D(16,(3,3),activation="relu"),

    layers.MaxPooling2D(),

    layers.Conv2D(32,(3,3),activation="relu"),

    layers.MaxPooling2D(),

    layers.Flatten(),

    layers.Dense(64,activation="relu"),

    layers.Dropout(0.3),

    layers.Dense(4,activation="softmax")

])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(

    optimizer="adam",

    loss="sparse_categorical_crossentropy",

    metrics=["accuracy"]

)

# %%
history = model.fit(

    train_dataset,

    validation_data=validation_dataset,

    epochs=30

)
# Out:
# Epoch 1/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.1875 - loss: 2.2987 - val_accuracy: 0.3750 - val_loss: 1.7702
# Epoch 2/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2188 - loss: 1.4919 - val_accuracy: 0.1250 - val_loss: 1.4045
# Epoch 3/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.3750 - loss: 1.3117 - val_accuracy: 0.3750 - val_loss: 1.3391
# Epoch 4/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4062 - loss: 1.3293 - val_accuracy: 0.2500 - val_loss: 1.3572
# Epoch 5/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5312 - loss: 1.2321 - val_accuracy: 0.2500 - val_loss: 1.4027
# Epoch 6/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5312 - loss: 1.1422 - val_accuracy: 0.5000 - val_loss: 1.4062
# Epoch 7/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.5625 - loss: 1.0942 - val_accuracy: 0.6250 - val_loss: 1.5034
# Epoch 8/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5938 - loss: 1.0508 - val_accuracy: 0.3750 - val_loss: 2.0178
# Epoch 9/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6250 - loss: 1.0945 - val_accuracy: 0.2500 - val_loss: 1.5436
# Epoch 10/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6875 - loss: 0.9794 - val_accuracy: 0.5000 - val_loss: 1.8949
# Epoch 11/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5312 - loss: 0.9641 - val_accuracy: 0.3750 - val_loss: 1.9766
# Epoch 12/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8438 - loss: 0.7708 - val_accuracy: 0.3750 - val_loss: 1.9771
# Epoch 13/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.6562 - loss: 0.7936 - val_accuracy: 0.3750 - val_loss: 2.4233
# Epoch 14/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7188 - loss: 0.7689 - val_accuracy: 0.2500 - val_loss: 2.4774
# Epoch 15/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7188 - loss: 0.7037 - val_accuracy: 0.1250 - val_loss: 2.5631
# Epoch 16/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7812 - loss: 0.6157 - val_accuracy: 0.3750 - val_loss: 2.4218
# Epoch 17/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7812 - loss: 0.5662 - val_accuracy: 0.5000 - val_loss: 2.7665
# Epoch 18/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6875 - loss: 0.7140 - val_accuracy: 0.1250 - val_loss: 2.1569
# Epoch 19/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8438 - loss: 0.4986 - val_accuracy: 0.5000 - val_loss: 1.9719
# Epoch 20/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.7812 - loss: 0.5771 - val_accuracy: 0.2500 - val_loss: 2.2694
# Epoch 21/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8438 - loss: 0.4224 - val_accuracy: 0.5000 - val_loss: 2.8165
# Epoch 22/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7812 - loss: 0.4279 - val_accuracy: 0.3750 - val_loss: 1.8084
# Epoch 23/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8438 - loss: 0.4710 - val_accuracy: 0.3750 - val_loss: 2.3930
# Epoch 24/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8438 - loss: 0.3601 - val_accuracy: 0.2500 - val_loss: 3.6994
# Epoch 25/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8438 - loss: 0.4859 - val_accuracy: 0.2500 - val_loss: 2.3476
# Epoch 26/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8750 - loss: 0.4636 - val_accuracy: 0.3750 - val_loss: 1.6185
# Epoch 27/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9375 - loss: 0.3995 - val_accuracy: 0.3750 - val_loss: 1.9234
# Epoch 28/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.7500 - loss: 0.6109 - val_accuracy: 0.3750 - val_loss: 4.1295
# Epoch 29/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.8750 - loss: 0.4028 - val_accuracy: 0.3750 - val_loss: 1.8260
# Epoch 30/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.7500 - loss: 0.5790 - val_accuracy: 0.3750 - val_loss: 1.6525

# %%
loss,accuracy = model.evaluate(validation_dataset)

print("Accuracy :",accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3750 - loss: 1.6525
# Accuracy : 0.375

# %%
plt.figure(figsize=(10,4))

plt.plot(history.history["accuracy"],label="Training")

plt.plot(history.history["val_accuracy"],label="Validation")

plt.xlabel("Epoch")

plt.ylabel("Accuracy")

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,4))

plt.plot(history.history["loss"],label="Training")

plt.plot(history.history["val_loss"],label="Validation")

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.legend()

plt.show()

# %%
predictions = model.predict(validation_dataset)

predicted_labels = np.argmax(predictions,axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step

# %%
index = 0

plt.figure(figsize=(12,8))

for images,labels in validation_dataset:

    images = images.numpy()

    labels = labels.numpy()

    for i in range(len(images)):

        plt.subplot(3,4,index+1)

        plt.imshow(images[i].astype("uint8"))

        actual = class_names[labels[i]]

        predicted = class_names[predicted_labels[index]]

        plt.title(f"P:{predicted}\nA:{actual}")

        plt.axis("off")

        index += 1

        if index==12:
            break

    if index==12:
        break

plt.tight_layout()

plt.show()

# %%
from tensorflow.keras.preprocessing import image

img = image.load_img(
    "/content/test2.jpeg",
    target_size=(128,128)
)

plt.imshow(img)

plt.axis("off")

plt.show()

# %%
img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array,axis=0)

# %%
layers.Rescaling(1./255)
# Out:
# <Rescaling name=rescaling_4, built=False>

# %%
prediction = model.predict(img_array)

predicted_class = class_names[np.argmax(prediction)]

confidence = np.max(prediction)*100

print("Prediction :",predicted_class)

print("Confidence :",confidence,"%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Prediction : happy
# Confidence : 92.79718 %

# %%
from tensorflow.keras.preprocessing import image

img = image.load_img(
    "/content/tes4.jpeg",
    target_size=(128,128)
)

plt.imshow(img)

plt.axis("off")

plt.show()

# %%
img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array,axis=0)

# %%
layers.Rescaling(1./255)
# Out:
# <Rescaling name=rescaling_8, built=False>

# %%
prediction = model.predict(img_array)

predicted_class = class_names[np.argmax(prediction)]

confidence = np.max(prediction)*100

print("Prediction :",predicted_class)

print("Confidence :",confidence,"%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Prediction : angry
# Confidence : 50.29232 %

# %%
from tensorflow.keras.preprocessing import image

img = image.load_img(
    "/content/test1.jpeg",
    target_size=(128,128)
)

plt.imshow(img)

plt.axis("off")

plt.show()

# %%
img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array,axis=0)

# %%
layers.Rescaling(1./255)
# Out:
# <Rescaling name=rescaling_7, built=False>

# %%
prediction = model.predict(img_array)

predicted_class = class_names[np.argmax(prediction)]

confidence = np.max(prediction)*100

print("Prediction :",predicted_class)

print("Confidence :",confidence,"%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction : happy
# Confidence : 53.784126 %
